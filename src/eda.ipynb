# %% [markdown]
# ## EDA

# %%
import pandas as pd
data_train = pd.read_csv("/Users/jonathan.sierks/01_Uni/10_DataMining/expedia-hotel-ranking/data/training_set_VU_DM.csv")
data_train.head(5)
# Out:
#    srch_id            date_time  site_id  visitor_location_country_id  \
# 0        1  2013-04-04 08:32:15       12                          187
# 1        1  2013-04-04 08:32:15       12                          187
# 2        1  2013-04-04 08:32:15       12                          187
# 3        1  2013-04-04 08:32:15       12                          187
# 4        1  2013-04-04 08:32:15       12                          187
#
#    visitor_hist_starrating  visitor_hist_adr_usd  prop_country_id  prop_id  \
# 0                      NaN                   NaN              219      893
# 1                      NaN                   NaN              219    10404
# 2                      NaN                   NaN              219    21315
# 3                      NaN                   NaN              219    27348
# 4                      NaN                   NaN              219    29604
#
#    prop_starrating  prop_review_score  ...  comp6_rate_percent_diff  \
# ...

# %%
df = data_train.copy()

# %%
df[df.click_bool == True].srch_id.count()
# Out:
# 221879

# %%
df[df.booking_bool == True].srch_id.count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[df.booking_bool == True].srch_id.count()
#
# NameError: name 'df' is not defined

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

df[df.booking_bool == True][:100]
# Out:
#       srch_id            date_time  site_id  visitor_location_country_id  \
# 12          1  2013-04-04 08:32:15       12                          187
# 63          6  2013-06-05 12:27:51       14                          100
# 68          8  2013-03-20 17:50:44        5                          219
# 194        21  2013-02-18 17:16:25       15                           55
# 211        25  2012-12-11 13:03:42        5                          219
# 243        28  2012-11-26 10:13:17        5                          219
# 274        29  2013-02-26 19:42:22       18                          129
# 312        30  2013-02-11 01:28:38       24                          216
# 346        36  2013-04-03 08:54:17       22                           92
# 387        39  2013-04-06 18:08:58        5                          219
# 428        42  2012-12-19 14:24:00       14                          100
# 467        44  2013-03-19 15:57:46       15                           55
# ...

# %%
df.date_time = pd.to_datetime(df.date_time)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4958347 entries, 0 to 4958346
# Data columns (total 54 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   srch_id                      int64
#  1   date_time                    datetime64[us]
#  2   site_id                      int64
#  3   visitor_location_country_id  int64
#  4   visitor_hist_starrating      float64
#  5   visitor_hist_adr_usd         float64
#  6   prop_country_id              int64
#  7   prop_id                      int64
#  8   prop_starrating              int64
#  9   prop_review_score            float64
#  10  prop_brand_bool              int64
#  11  prop_location_score1         float64
#  12  prop_location_score2         float64
#  13  prop_log_historical_price    float64
#  14  position                     int64
#  15  price_usd                    float64
#  16  promotion_flag               int64
#  17  srch_destination_id          int64
# ...

# %%
df.describe()
# Out:
#             srch_id                   date_time       site_id  \
# count  4.958347e+06                     4958347  4.958347e+06
# mean   1.663666e+05  2013-03-11 06:19:37.890844  9.953133e+00
# min    1.000000e+00         2012-11-01 00:08:29  1.000000e+00
# 25%    8.293600e+04         2013-01-14 17:47:32  5.000000e+00
# 50%    1.665070e+05         2013-03-13 20:13:18  5.000000e+00
# 75%    2.497240e+05         2013-05-10 00:01:38  1.400000e+01
# max    3.327850e+05         2013-06-30 23:58:24  3.400000e+01
# std    9.611223e+04                         NaN  7.646890e+00
#
#        visitor_location_country_id  visitor_hist_starrating  \
# count                 4.958347e+06            251866.000000
# mean                  1.753405e+02                 3.374334
# min                   1.000000e+00                 1.410000
# 25%                   1.000000e+02                 2.920000
# 50%                   2.190000e+02                 3.450000
# ...

# %%
pd.isna(df).count()
# Out:
# srch_id                        4958347
# date_time                      4958347
# site_id                        4958347
# visitor_location_country_id    4958347
# visitor_hist_starrating        4958347
# visitor_hist_adr_usd           4958347
# prop_country_id                4958347
# prop_id                        4958347
# prop_starrating                4958347
# prop_review_score              4958347
# prop_brand_bool                4958347
# prop_location_score1           4958347
# prop_location_score2           4958347
# prop_log_historical_price      4958347
# position                       4958347
# price_usd                      4958347
# promotion_flag                 4958347
# srch_destination_id            4958347
# srch_length_of_stay            4958347
# srch_booking_window            4958347
# srch_adults_count              4958347
# srch_children_count            4958347
# srch_room_count                4958347
# srch_saturday_night_bool       4958347
# ...

# %%
df.isna().sum()
# Out:
# srch_id                              0
# date_time                            0
# site_id                              0
# visitor_location_country_id          0
# visitor_hist_starrating        4706481
# visitor_hist_adr_usd           4705359
# prop_country_id                      0
# prop_id                              0
# prop_starrating                      0
# prop_review_score                 7364
# prop_brand_bool                      0
# prop_location_score1                 0
# prop_location_score2           1090348
# prop_log_historical_price            0
# position                             0
# price_usd                            0
# promotion_flag                       0
# srch_destination_id                  0
# srch_length_of_stay                  0
# srch_booking_window                  0
# srch_adults_count                    0
# srch_children_count                  0
# srch_room_count                      0
# srch_saturday_night_bool             0
# ...

# %%
df.srch_id.nunique()
# Out:
# 199795

# %%
df.groupby("srch_id").size().describe()
# Out:
# count    199795.000000
# mean         24.817173
# std           9.113335
# min           5.000000
# 25%          18.000000
# 50%          29.000000
# 75%          32.000000
# max          38.000000
# dtype: float64

# %%
df.srch_id.count()
# Out:
# 4958347

# %%
df.groupby("prop_id").size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.groupby("prop_id").size()
#
# NameError: name 'df' is not defined

# %%
print(2)
# Out:
# 2
